# %%
import pandas as pd
from pycaret.regression import *

df = pd.read_csv("../../data/rumah123_cleaned.csv")

df = df.drop(columns=["Unnamed: 0", "name"], errors='ignore')
df
# Out:
#        price               location  bedroom  bathroom  land_area  \
# 0       1680      Rungkut, Surabaya        3         3         67
# 1        950  Medokan Ayu, Surabaya        3         3         72
# 2        500     Wonorejo, Surabaya        2         1         30
# 3        950     Sukolilo, Surabaya        2         2         50
# 4        600      Kebraon, Surabaya        2         1         50
# ...      ...                    ...      ...       ...        ...
# 37514    730     Sidoarjo, Sidoarjo        3         1        144
# 37515   1200       Sedati, Sidoarjo        3         2         90
# 37516    660     Sidoarjo, Sidoarjo        2         1         90
# 37517    600       Sedati, Sidoarjo        2         1         84
# 37518   3650         Waru, Sidoarjo        4         3        300
#
#        building_area
# 0                120
# 1                140
# 2                 36
# 3                 55
# 4                 56
# ...              ...
# 37514            120
# 37515            112
# 37516             70
# 37517             60
# 37518            420
#
# [37519 rows x 6 columns]

# %%
df.duplicated().sum()
# Out:
# 14396

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
lokasi_count = df['location'].value_counts()
lokasi_count
# Out:
# location
# Rungkut, Surabaya             2363
# Sidoarjo, Sidoarjo            2076
# Waru, Sidoarjo                1416
# Wiyung, Surabaya              1000
# Gununganyar, Surabaya          884
#                               ...
# Karang Poh, Surabaya             1
# Dr Sutomo, Surabaya              1
# Kureksari, Surabaya              1
# Gundih, Surabaya                 1
# Bendungan Bening, Sidoarjo       1
# Name: count, Length: 142, dtype: int64

# %%
# lokasi_kecil = lokasi_count[lokasi_count < 10].index
# df['location'] = df['location'].apply(lambda x: 'Lainnya' if x in lokasi_kecil else x)
# (df['location'] == 'Lainnya').value_counts()

# %%
# import ydata_profiling as pp

# profile = pp.ProfileReport(df)
# profile.to_file('pp_report/Report_rumah123_full.html')

# %%
setup(
    df, 
    target='price',
    transform_target=True,
    normalize=True, 
    normalize_method='zscore',
    remove_outliers=True, 
    outliers_threshold=0.05,
    categorical_features=['location'],
    session_id=42
)
# Out:
# <style type="text/css">
# #T_6e9fa_row9_col1, #T_6e9fa_row15_col1, #T_6e9fa_row17_col1, #T_6e9fa_row19_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6e9fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e9fa_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6e9fa_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e9fa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6e9fa_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6e9fa_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_6e9fa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6e9fa_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6e9fa_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
#       <th id="T_6e9fa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6e9fa_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_6e9fa_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_6e9fa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6e9fa_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_6e9fa_row3_col1" class="data row3 col1" >(23123, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_6e9fa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6e9fa_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_6e9fa_row4_col1" class="data row4 col1" >(22313, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_6e9fa_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6e9fa_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_6e9fa_row5_col1" class="data row5 col1" >(15376, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_6e9fa_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6e9fa_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_6e9fa_row6_col1" class="data row6 col1" >(6937, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_6e9fa_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6e9fa_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_6e9fa_row7_col1" class="data row7 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_6e9fa_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6e9fa_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_6e9fa_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6e9fa_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6e9fa_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_6e9fa_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6e9fa_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6e9fa_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_6e9fa_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_6e9fa_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6e9fa_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_6e9fa_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_6e9fa_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6e9fa_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_6e9fa_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_6e9fa_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6e9fa_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_6e9fa_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_6e9fa_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6e9fa_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_6e9fa_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_6e9fa_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6e9fa_row15_col0" class="data row15 col0" >Remove outliers</td>
#       <td id="T_6e9fa_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6e9fa_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_6e9fa_row16_col0" class="data row16 col0" >Outliers threshold</td>
#       <td id="T_6e9fa_row16_col1" class="data row16 col1" >0.050000</td>
#     </tr>
#     <tr>
#       <th id="T_6e9fa_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_6e9fa_row17_col0" class="data row17 col0" >Normalize</td>
#       <td id="T_6e9fa_row17_col1" class="data row17 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6e9fa_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_6e9fa_row18_col0" class="data row18 col0" >Normalize method</td>
#       <td id="T_6e9fa_row18_col1" class="data row18 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_6e9fa_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_6e9fa_row19_col0" class="data row19 col0" >Transform target</td>
#       <td id="T_6e9fa_row19_col1" class="data row19 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6e9fa_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_6e9fa_row20_col0" class="data row20 col0" >Transform target method</td>
#       <td id="T_6e9fa_row20_col1" class="data row20 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_6e9fa_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_6e9fa_row21_col0" class="data row21 col0" >Fold Generator</td>
#       <td id="T_6e9fa_row21_col1" class="data row21 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_6e9fa_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_6e9fa_row22_col0" class="data row22 col0" >Fold Number</td>
#       <td id="T_6e9fa_row22_col1" class="data row22 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_6e9fa_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_6e9fa_row23_col0" class="data row23 col0" >CPU Jobs</td>
#       <td id="T_6e9fa_row23_col1" class="data row23 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_6e9fa_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_6e9fa_row24_col0" class="data row24 col0" >Use GPU</td>
#       <td id="T_6e9fa_row24_col1" class="data row24 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6e9fa_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_6e9fa_row25_col0" class="data row25 col0" >Log Experiment</td>
#       <td id="T_6e9fa_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6e9fa_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_6e9fa_row26_col0" class="data row26 col0" >Experiment Name</td>
#       <td id="T_6e9fa_row26_col1" class="data row26 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_6e9fa_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_6e9fa_row27_col0" class="data row27 col0" >USI</td>
#       <td id="T_6e9fa_row27_col1" class="data row27 col1" >79dd</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_11619 th {
#   text-align: left;
# }
# #T_11619_row0_col0, #T_11619_row0_col1, #T_11619_row0_col2, #T_11619_row0_col5, #T_11619_row0_col6, #T_11619_row1_col0, #T_11619_row1_col1, #T_11619_row1_col3, #T_11619_row1_col4, #T_11619_row1_col5, #T_11619_row1_col6, #T_11619_row2_col0, #T_11619_row2_col1, #T_11619_row2_col2, #T_11619_row2_col3, #T_11619_row2_col4, #T_11619_row2_col6, #T_11619_row3_col0, #T_11619_row3_col1, #T_11619_row3_col2, #T_11619_row3_col3, #T_11619_row3_col4, #T_11619_row3_col5, #T_11619_row3_col6, #T_11619_row4_col0, #T_11619_row4_col2, #T_11619_row4_col3, #T_11619_row4_col4, #T_11619_row4_col5, #T_11619_row5_col0, #T_11619_row5_col1, #T_11619_row5_col2, #T_11619_row5_col3, #T_11619_row5_col4, #T_11619_row5_col5, #T_11619_row5_col6, #T_11619_row6_col0, #T_11619_row6_col1, #T_11619_row6_col2, #T_11619_row6_col3, #T_11619_row6_col4, #T_11619_row6_col5, #T_11619_row6_col6, #T_11619_row7_col0, #T_11619_row7_col1, #T_11619_row7_col2, #T_11619_row7_col3, #T_11619_row7_col4, #T_11619_row7_col5, #T_11619_row7_col6, #T_11619_row8_col0, #T_11619_row8_col1, #T_11619_row8_col2, #T_11619_row8_col3, #T_11619_row8_col4, #T_11619_row8_col5, #T_11619_row8_col6, #T_11619_row9_col0, #T_11619_row9_col1, #T_11619_row9_col2, #T_11619_row9_col3, #T_11619_row9_col4, #T_11619_row9_col5, #T_11619_row9_col6, #T_11619_row10_col0, #T_11619_row10_col1, #T_11619_row10_col2, #T_11619_row10_col3, #T_11619_row10_col4, #T_11619_row10_col5, #T_11619_row10_col6, #T_11619_row11_col0, #T_11619_row11_col1, #T_11619_row11_col2, #T_11619_row11_col3, #T_11619_row11_col4, #T_11619_row11_col5, #T_11619_row11_col6, #T_11619_row12_col0, #T_11619_row12_col1, #T_11619_row12_col2, #T_11619_row12_col3, #T_11619_row12_col4, #T_11619_row12_col5, #T_11619_row12_col6 {
#   text-align: left;
# }
# #T_11619_row0_col3, #T_11619_row0_col4, #T_11619_row1_col2, #T_11619_row2_col5, #T_11619_row4_col1, #T_11619_row4_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_11619_row0_col7, #T_11619_row1_col7, #T_11619_row2_col7, #T_11619_row3_col7, #T_11619_row4_col7, #T_11619_row5_col7, #T_11619_row6_col7, #T_11619_row8_col7, #T_11619_row9_col7, #T_11619_row10_col7, #T_11619_row11_col7, #T_11619_row12_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_11619_row7_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_11619">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11619_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_11619_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_11619_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_11619_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_11619_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_11619_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_11619_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_11619_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11619_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_11619_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_11619_row0_col1" class="data row0 col1" >342.5367</td>
#       <td id="T_11619_row0_col2" class="data row0 col2" >5747227.8452</td>
#       <td id="T_11619_row0_col3" class="data row0 col3" >1805.8463</td>
#       <td id="T_11619_row0_col4" class="data row0 col4" >0.2798</td>
#       <td id="T_11619_row0_col5" class="data row0 col5" >0.3290</td>
#       <td id="T_11619_row0_col6" class="data row0 col6" >0.2515</td>
#       <td id="T_11619_row0_col7" class="data row0 col7" >0.2250</td>
#     </tr>
#     <tr>
#       <th id="T_11619_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_11619_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_11619_row1_col1" class="data row1 col1" >327.5690</td>
#       <td id="T_11619_row1_col2" class="data row1 col2" >5736048.1843</td>
#       <td id="T_11619_row1_col3" class="data row1 col3" >1807.0663</td>
#       <td id="T_11619_row1_col4" class="data row1 col4" >0.2750</td>
#       <td id="T_11619_row1_col5" class="data row1 col5" >0.3189</td>
#       <td id="T_11619_row1_col6" class="data row1 col6" >0.2345</td>
#       <td id="T_11619_row1_col7" class="data row1 col7" >0.5740</td>
#     </tr>
#     <tr>
#       <th id="T_11619_level0_row2" class="row_heading level0 row2" >catboost</th>
#       <td id="T_11619_row2_col0" class="data row2 col0" >CatBoost Regressor</td>
#       <td id="T_11619_row2_col1" class="data row2 col1" >330.3755</td>
#       <td id="T_11619_row2_col2" class="data row2 col2" >5774020.2732</td>
#       <td id="T_11619_row2_col3" class="data row2 col3" >1819.4930</td>
#       <td id="T_11619_row2_col4" class="data row2 col4" >0.2612</td>
#       <td id="T_11619_row2_col5" class="data row2 col5" >0.3176</td>
#       <td id="T_11619_row2_col6" class="data row2 col6" >0.2365</td>
#       <td id="T_11619_row2_col7" class="data row2 col7" >3.9360</td>
#     </tr>
#     <tr>
#       <th id="T_11619_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_11619_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_11619_row3_col1" class="data row3 col1" >332.7015</td>
#       <td id="T_11619_row3_col2" class="data row3 col2" >5795625.7058</td>
#       <td id="T_11619_row3_col3" class="data row3 col3" >1827.1677</td>
#       <td id="T_11619_row3_col4" class="data row3 col4" >0.2525</td>
#       <td id="T_11619_row3_col5" class="data row3 col5" >0.3204</td>
#       <td id="T_11619_row3_col6" class="data row3 col6" >0.2373</td>
#       <td id="T_11619_row3_col7" class="data row3 col7" >1.1750</td>
#     </tr>
#     <tr>
#       <th id="T_11619_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_11619_row4_col0" class="data row4 col0" >Random Forest Regressor</td>
#       <td id="T_11619_row4_col1" class="data row4 col1" >326.7267</td>
#       <td id="T_11619_row4_col2" class="data row4 col2" >5826581.1724</td>
#       <td id="T_11619_row4_col3" class="data row4 col3" >1846.6573</td>
#       <td id="T_11619_row4_col4" class="data row4 col4" >0.2197</td>
#       <td id="T_11619_row4_col5" class="data row4 col5" >0.3222</td>
#       <td id="T_11619_row4_col6" class="data row4 col6" >0.2311</td>
#       <td id="T_11619_row4_col7" class="data row4 col7" >0.5350</td>
#     </tr>
#     <tr>
#       <th id="T_11619_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_11619_row5_col0" class="data row5 col0" >K Neighbors Regressor</td>
#       <td id="T_11619_row5_col1" class="data row5 col1" >358.6766</td>
#       <td id="T_11619_row5_col2" class="data row5 col2" >5865244.0880</td>
#       <td id="T_11619_row5_col3" class="data row5 col3" >1861.3439</td>
#       <td id="T_11619_row5_col4" class="data row5 col4" >0.2017</td>
#       <td id="T_11619_row5_col5" class="data row5 col5" >0.3482</td>
#       <td id="T_11619_row5_col6" class="data row5 col6" >0.2601</td>
#       <td id="T_11619_row5_col7" class="data row5 col7" >0.0840</td>
#     </tr>
#     <tr>
#       <th id="T_11619_level0_row6" class="row_heading level0 row6" >lasso</th>
#       <td id="T_11619_row6_col0" class="data row6 col0" >Lasso Regression</td>
#       <td id="T_11619_row6_col1" class="data row6 col1" >578.8431</td>
#       <td id="T_11619_row6_col2" class="data row6 col2" >6269812.9341</td>
#       <td id="T_11619_row6_col3" class="data row6 col3" >2008.7738</td>
#       <td id="T_11619_row6_col4" class="data row6 col4" >-0.0352</td>
#       <td id="T_11619_row6_col5" class="data row6 col5" >0.5534</td>
#       <td id="T_11619_row6_col6" class="data row6 col6" >0.4928</td>
#       <td id="T_11619_row6_col7" class="data row6 col7" >0.0760</td>
#     </tr>
#     <tr>
#       <th id="T_11619_level0_row7" class="row_heading level0 row7" >en</th>
#       <td id="T_11619_row7_col0" class="dat

# %%
tuned_model = tune_model(best, search_library='scikit-optimize', search_algorithm='bayesian')
# Out:
# <style type="text/css">
# #T_3df8f_row10_col0, #T_3df8f_row10_col1, #T_3df8f_row10_col2, #T_3df8f_row10_col3, #T_3df8f_row10_col4, #T_3df8f_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_3df8f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3df8f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_3df8f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_3df8f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_3df8f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_3df8f_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_3df8f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3df8f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3df8f_row0_col0" class="data row0 col0" >492.8411</td>
#       <td id="T_3df8f_row0_col1" class="data row0 col1" >31440201.4867</td>
#       <td id="T_3df8f_row0_col2" class="data row0 col2" >5607.1563</td>
#       <td id="T_3df8f_row0_col3" class="data row0 col3" >0.0087</td>
#       <td id="T_3df8f_row0_col4" class="data row0 col4" >0.3641</td>
#       <td id="T_3df8f_row0_col5" class="data row0 col5" >0.2611</td>
#     </tr>
#     <tr>
#       <th id="T_3df8f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3df8f_row1_col0" class="data row1 col0" >306.5166</td>
#       <td id="T_3df8f_row1_col1" class="data row1 col1" >524757.9064</td>
#       <td id="T_3df8f_row1_col2" class="data row1 col2" >724.4018</td>
#       <td id="T_3df8f_row1_col3" class="data row1 col3" >0.4761</td>
#       <td id="T_3df8f_row1_col4" class="data row1 col4" >0.3144</td>
#       <td id="T_3df8f_row1_col5" class="data row1 col5" >0.2450</td>
#     </tr>
#     <tr>
#       <th id="T_3df8f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3df8f_row2_col0" class="data row2 col0" >320.1748</td>
#       <td id="T_3df8f_row2_col1" class="data row2 col1" >1180591.7404</td>
#       <td id="T_3df8f_row2_col2" class="data row2 col2" >1086.5504</td>
#       <td id="T_3df8f_row2_col3" class="data row2 col3" >0.3362</td>
#       <td id="T_3df8f_row2_col4" class="data row2 col4" >0.3298</td>
#       <td id="T_3df8f_row2_col5" class="data row2 col5" >0.2556</td>
#     </tr>
#     <tr>
#       <th id="T_3df8f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3df8f_row3_col0" class="data row3 col0" >318.7371</td>
#       <td id="T_3df8f_row3_col1" class="data row3 col1" >860469.2690</td>
#       <td id="T_3df8f_row3_col2" class="data row3 col2" >927.6148</td>
#       <td id="T_3df8f_row3_col3" class="data row3 col3" >0.3400</td>
#       <td id="T_3df8f_row3_col4" class="data row3 col4" >0.3236</td>
#       <td id="T_3df8f_row3_col5" class="data row3 col5" >0.2481</td>
#     </tr>
#     <tr>
#       <th id="T_3df8f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3df8f_row4_col0" class="data row4 col0" >281.9706</td>
#       <td id="T_3df8f_row4_col1" class="data row4 col1" >377283.9696</td>
#       <td id="T_3df8f_row4_col2" class="data row4 col2" >614.2345</td>
#       <td id="T_3df8f_row4_col3" class="data row4 col3" >0.4555</td>
#       <td id="T_3df8f_row4_col4" class="data row4 col4" >0.3108</td>
#       <td id="T_3df8f_row4_col5" class="data row4 col5" >0.2453</td>
#     </tr>
#     <tr>
#       <th id="T_3df8f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3df8f_row5_col0" class="data row5 col0" >320.6840</td>
#       <td id="T_3df8f_row5_col1" class="data row5 col1" >657969.8760</td>
#       <td id="T_3df8f_row5_col2" class="data row5 col2" >811.1534</td>
#       <td id="T_3df8f_row5_col3" class="data row5 col3" >0.3268</td>
#       <td id="T_3df8f_row5_col4" class="data row5 col4" >0.3286</td>
#       <td id="T_3df8f_row5_col5" class="data row5 col5" >0.2591</td>
#     </tr>
#     <tr>
#       <th id="T_3df8f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3df8f_row6_col0" class="data row6 col0" >318.4418</td>
#       <td id="T_3df8f_row6_col1" class="data row6 col1" >1405592.3573</td>
#       <td id="T_3df8f_row6_col2" class="data row6 col2" >1185.5768</td>
#       <td id="T_3df8f_row6_col3" class="data row6 col3" >0.2883</td>
#       <td id="T_3df8f_row6_col4" class="data row6 col4" >0.3146</td>
#       <td id="T_3df8f_row6_col5" class="data row6 col5" >0.2506</td>
#     </tr>
#     <tr>
#       <th id="T_3df8f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3df8f_row7_col0" class="data row7 col0" >402.6312</td>
#       <td id="T_3df8f_row7_col1" class="data row7 col1" >11794183.2575</td>
#       <td id="T_3df8f_row7_col2" class="data row7 col2" >3434.2660</td>
#       <td id="T_3df8f_row7_col3" class="data row7 col3" >0.0289</td>
#       <td id="T_3df8f_row7_col4" class="data row7 col4" >0.3427</td>
#       <td id="T_3df8f_row7_col5" class="data row7 col5" >0.2395</td>
#     </tr>
#     <tr>
#       <th id="T_3df8f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3df8f_row8_col0" class="data row8 col0" >304.7048</td>
#       <td id="T_3df8f_row8_col1" class="data row8 col1" >611550.2751</td>
#       <td id="T_3df8f_row8_col2" class="data row8 col2" >782.0168</td>
#       <td id="T_3df8f_row8_col3" class="data row8 col3" >0.3698</td>
#       <td id="T_3df8f_row8_col4" class="data row8 col4" >0.3228</td>
#       <td id="T_3df8f_row8_col5" class="data row8 col5" >0.2542</td>
#     </tr>
#     <tr>
#       <th id="T_3df8f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3df8f_row9_col0" class="data row9 col0" >363.8489</td>
#       <td id="T_3df8f_row9_col1" class="data row9 col1" >8620078.7572</td>
#       <td id="T_3df8f_row9_col2" class="data row9 col2" >2935.9971</td>
#       <td id="T_3df8f_row9_col3" class="data row9 col3" >0.0870</td>
#       <td id="T_3df8f_row9_col4" class="data row9 col4" >0.3287</td>
#       <td id="T_3df8f_row9_col5" class="data row9 col5" >0.2609</td>
#     </tr>
#     <tr>
#       <th id="T_3df8f_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_3df8f_row10_col0" class="data row10 col0" >343.0551</td>
#       <td id="T_3df8f_row10_col1" class="data row10 col1" >5747267.8895</td>
#       <td id="T_3df8f_row10_col2" class="data row10 col2" >1810.8968</td>
#       <td id="T_3df8f_row10_col3" class="data row10 col3" >0.2717</td>
#       <td id="T_3df8f_row10_col4" class="data row10 col4" >0.3280</td>
#       <td id="T_3df8f_row10_col5" class="data row10 col5" >0.2519</td>
#     </tr>
#     <tr>
#       <th id="T_3df8f_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_3df8f_row11_col0" class="data row11 col0" >59.3092</td>
#       <td id="T_3df8f_row11_col1" class="data row11 col1" >9364392.2938</td>
#       <td id="T_3df8f_row11_col2" class="data row11 col2" >1570.9617</td>
#       <td id="T_3df8f_row11_col3" class="data row11 col3" >0.1611</td>
#       <td id="T_3df8f_row11_col4" class="data row11 col4" >0.0149</td>
#       <td id="T_3df8f_row11_col5" class="data row11 col5" >0.0071</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
# new_data = df.copy()
# new_data.drop('price', axis=1, inplace=True)
# new_data.head()
# Out:
#                 location  bedroom  bathroom  land_area  building_area
# 0      Rungkut, Surabaya        3         3         67            120
# 1  Medokan Ayu, Surabaya        3         3         72            140
# 2     Wonorejo, Surabaya        2         1         30             36
# 3     Sukolilo, Surabaya        2         2         50             55
# 4      Kebraon, Surabaya        2         1         50             56

# %%
# predictions = predict_model(tuned_model, data = new_data)
# predictions.head()
# Out:
#                 location  bedroom  bathroom  land_area  building_area  \
# 0      Rungkut, Surabaya        3         3         67            120
# 1  Medokan Ayu, Surabaya        3         3         72            140
# 2     Wonorejo, Surabaya        2         1         30             36
# 3     Sukolilo, Surabaya        2         2         50             55
# 4      Kebraon, Surabaya        2         1         50             56
#
#    prediction_label
# 0       1329.153096
# 1       1127.126952
# 2        412.174211
# 3        832.374166
# 4        668.827038

# %%
# save_model(tuned_model, 'full-cb')
